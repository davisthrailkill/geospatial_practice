# %%
# import packages
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium

# %matplotlib inline

# %%
# read in neighborhood data
neighborhoods = gpd.read_file("data/Neighborhood Association Boundaries (GIS).geojson")
neighborhoods.head()
# Out:
#                    name                                           geometry
# 0  Historic Buena Vista  (POLYGON ((-86.79511056795417 36.1757596496334...
# 1        Charlotte Park  (POLYGON ((-86.87459668651866 36.1575770268129...
# 2              Hillwood  (POLYGON ((-86.87613708067906 36.1355409894979...
# 3            West Meade  (POLYGON ((-86.9038380396094 36.1255414807897,...
# 4          White Bridge  (POLYGON ((-86.86321427797685 36.1288622289404...

# %%
# read in bike racks data
bike_racks = pd.read_csv("data/BikeRacks.csv")
bike_racks.head()
# Out:
#                                         the_geom  OBJECTID  Type  Domain  \
# 0   POINT (-86.65545277788506 36.04992777776401)         1  Rack  Public
# 1  POINT (-86.63406252260503 36.185280037810124)         2  Rack  Public
# 2  POINT (-86.62067056966663 36.158421598626106)         3  Rack  Public
# 3   POINT (-86.6865259267347 36.187546694847676)         4  Rack  Public
# 4  POINT (-86.76218008308803 36.172455406173995)         5  Rack  Public
#
#      Status  IDNumber  Quantity               Location  Capacity        LON  \
# 0  Existing       113         1                   Mall        12 -86.655453
# 1  Existing       114         2               Greenway         4 -86.634063
# 2  Proposed       256         0          Park/Greenway         0 -86.620671
# 3  Existing       115         1          Park/Greenway         5 -86.686526
# 4  Existing       103         3  Park/Community Center        15 -86.762180
#
#          LAT                                         Detail_Loc   Data_Colle
# 0  36.049928                                Hickory Hollow Mall  Health Dept
# 1  36.185280    Stones River Greenway - Donelson/Hermitage Area  Health Dept
# 2  36.158422      Percy Priest Reservoir, Stones River Greenway  Health Dept
# 3  36.187547  Two Rivers Golf Course, Stones River Greenway ...  Health Dept
# 4  36.172455                       East Park & Community Center  Health Dept

# %%
# rename columns
bike_racks.columns = ['Geom','ID','Type','Domain','Status','IDNumber','Quantity','Location','Capacity','Lng','Lat','Detail','Data_Coll']
bike_racks.head()
# Out:
#                                             Geom  ID  Type  Domain    Status  \
# 0   POINT (-86.65545277788506 36.04992777776401)   1  Rack  Public  Existing
# 1  POINT (-86.63406252260503 36.185280037810124)   2  Rack  Public  Existing
# 2  POINT (-86.62067056966663 36.158421598626106)   3  Rack  Public  Proposed
# 3   POINT (-86.6865259267347 36.187546694847676)   4  Rack  Public  Existing
# 4  POINT (-86.76218008308803 36.172455406173995)   5  Rack  Public  Existing
#
#    IDNumber  Quantity               Location  Capacity        Lng        Lat  \
# 0       113         1                   Mall        12 -86.655453  36.049928
# 1       114         2               Greenway         4 -86.634063  36.185280
# 2       256         0          Park/Greenway         0 -86.620671  36.158422
# 3       115         1          Park/Greenway         5 -86.686526  36.187547
# 4       103         3  Park/Community Center        15 -86.762180  36.172455
#
#                                               Detail    Data_Coll
# 0                                Hickory Hollow Mall  Health Dept
# 1    Stones River Greenway - Donelson/Hermitage Area  Health Dept
# 2      Percy Priest Reservoir, Stones River Greenway  Health Dept
# 3  Two Rivers Golf Course, Stones River Greenway ...  Health Dept
# 4                       East Park & Community Center  Health Dept

# %%
# read in MTA stops data
mta_stops = pd.read_csv("data/mta_stops.csv")
mta_stops.head()
# Out:
#    Stop ID Number Stop Abbreviation                         StopName  Shelter  \
# 0            1788           100OAKS                    100 OAKS MALL        1
# 1            1792          POWPOWNM        POWELL AVE & POWELL PL NB        0
# 2            1785          BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0
# 3            1787          BRABERNM      BRANSFORD AVE & BERRY RD NB        0
# 4             461          BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0
#
#    Bench  Route Number Route Name  Longitude   Latitude  \
# 0      1             1  VINE HILL -86.762639  36.106851
# 1      0             1  VINE HILL -86.765569  36.108232
# 2      1             1  VINE HILL -86.766280  36.116603
# 3      0             1  VINE HILL -86.765494  36.121603
# 4      0             1  VINE HILL -86.765827  36.124624
#
#            Mapped Location
# 0  (36.106851, -86.762639)
# 1  (36.108232, -86.765569)
# 2  (36.116603, -86.766280)
# 3  (36.121603, -86.765494)
# 4  (36.124624, -86.765827)

# %%
# rename columns
mta_stops.columns = ['Stop_ID_Number','Stop_Abbreviation','Stop_Name','Shelter','Bench','Route_Number','Route_Name','Lng','Lat','Mapped_Loc']
mta_stops.head()
# Out:
#    Stop_ID_Number Stop_Abbreviation                        Stop_Name  Shelter  \
# 0            1788           100OAKS                    100 OAKS MALL        1
# 1            1792          POWPOWNM        POWELL AVE & POWELL PL NB        0
# 2            1785          BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0
# 3            1787          BRABERNM      BRANSFORD AVE & BERRY RD NB        0
# 4             461          BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0
#
#    Bench  Route_Number Route_Name        Lng        Lat  \
# 0      1             1  VINE HILL -86.762639  36.106851
# 1      0             1  VINE HILL -86.765569  36.108232
# 2      1             1  VINE HILL -86.766280  36.116603
# 3      0             1  VINE HILL -86.765494  36.121603
# 4      0             1  VINE HILL -86.765827  36.124624
#
#                 Mapped_Loc
# 0  (36.106851, -86.762639)
# 1  (36.108232, -86.765569)
# 2  (36.116603, -86.766280)
# 3  (36.121603, -86.765494)
# 4  (36.124624, -86.765827)

# %%
bike_racks['Geom'] = bike_racks.apply(lambda x: Point((float(x.Lng), float(x.Lat))), axis=1)

# %%
mta_stops['Mapped_Loc'] = mta_stops.apply(lambda x: Point((float(x.Lng), float(x.Lat))), axis=1)

# %%
bike_racks_geo = gpd.GeoDataFrame(bike_racks, crs = neighborhoods.crs, geometry = bike_racks.Geom)

# %%
mta_stops_geo = gpd.GeoDataFrame(mta_stops, crs = neighborhoods.crs, geometry = mta_stops.Mapped_Loc)

# %%
bike_racks_geo.head()
# Out:
#                                        Geom  ID  Type  Domain    Status  \
# 0  POINT (-86.65545277790001 36.0499277778)   1  Rack  Public  Existing
# 1  POINT (-86.6340625226 36.18528003780001)   2  Rack  Public  Existing
# 2      POINT (-86.6206705697 36.1584215986)   3  Rack  Public  Proposed
# 3      POINT (-86.6865259267 36.1875466948)   4  Rack  Public  Existing
# 4  POINT (-86.76218008309999 36.1724554062)   5  Rack  Public  Existing
#
#    IDNumber  Quantity               Location  Capacity        Lng        Lat  \
# 0       113         1                   Mall        12 -86.655453  36.049928
# 1       114         2               Greenway         4 -86.634063  36.185280
# 2       256         0          Park/Greenway         0 -86.620671  36.158422
# 3       115         1          Park/Greenway         5 -86.686526  36.187547
# 4       103         3  Park/Community Center        15 -86.762180  36.172455
#
#                                               Detail    Data_Coll  \
# 0                                Hickory Hollow Mall  Health Dept
# 1    Stones River Greenway - Donelson/Hermitage Area  Health Dept
# 2      Percy Priest Reservoir, Stones River Greenway  Health Dept
# 3  Two Rivers Golf Course, Stones River Greenway ...  Health Dept
# 4                       East Park & Community Center  Health Dept
#
#                                    geometry
# 0  POINT (-86.65545277790001 36.0499277778)
# 1  POINT (-86.6340625226 36.18528003780001)
# 2      POINT (-86.6206705697 36.1584215986)
# 3      POINT (-86.6865259267 36.1875466948)
# 4  POINT (-86.76218008309999 36.1724554062)

# %%
mta_stops_geo.head()
# Out:
#    Stop_ID_Number Stop_Abbreviation                        Stop_Name  Shelter  \
# 0            1788           100OAKS                    100 OAKS MALL        1
# 1            1792          POWPOWNM        POWELL AVE & POWELL PL NB        0
# 2            1785          BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0
# 3            1787          BRABERNM      BRANSFORD AVE & BERRY RD NB        0
# 4             461          BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0
#
#    Bench  Route_Number Route_Name        Lng        Lat  \
# 0      1             1  VINE HILL -86.762639  36.106851
# 1      0             1  VINE HILL -86.765569  36.108232
# 2      1             1  VINE HILL -86.766280  36.116603
# 3      0             1  VINE HILL -86.765494  36.121603
# 4      0             1  VINE HILL -86.765827  36.124624
#
#                              Mapped_Loc                              geometry
# 0  POINT (-86.76263900000001 36.106851)  POINT (-86.76263900000001 36.106851)
# 1          POINT (-86.765569 36.108232)          POINT (-86.765569 36.108232)
# 2  POINT (-86.76628000000001 36.116603)  POINT (-86.76628000000001 36.116603)
# 3  POINT (-86.76549399999999 36.121603)  POINT (-86.76549399999999 36.121603)
# 4          POINT (-86.765827 36.124624)          POINT (-86.765827 36.124624)

# %%
# join the bike racks with neighborhoods
nash_bikes = gpd.sjoin(bike_racks_geo, neighborhoods, op = 'within')
nash_bikes.head()
# Out:
#                                          Geom   ID  Type  Domain  \
# 4    POINT (-86.76218008309999 36.1724554062)    5  Rack  Public
# 111      POINT (-86.7603189731 36.1722220733)  112  Rack  Public
# 393      POINT (-86.7587196799 36.1740162738)  394  Rack  Public
# 394  POINT (-86.76031268049999 36.1722879774)  395  Rack  Public
# 395      POINT (-86.7602654582 36.1722096836)  396  Rack  Public
#
#               Status  IDNumber  Quantity               Location  Capacity  \
# 4           Existing       103         3  Park/Community Center        15
# 111         Proposed       312         0      Elementary School         0
# 393  Future Artistic       415         0                   Park         0
# 394  Future Artistic       416         0                   Park         0
# 395  Future Artistic       417         0                   Park         0
#
#            Lng        Lat                                     Detail  \
# 4   -86.762180  36.172455               East Park & Community Center
# 111 -86.760319  36.172222                   Warner Elementary School
# 393 -86.758720  36.174016         East Park - Woodland St @ S 8th St
# 394 -86.760313  36.172288  East Park - Warner Public School Entrance
# 395 -86.760265  36.172210  East Park - Warner Public School Entrance
#
#        Data_Coll                                  geometry  index_right  \
# 4    Health Dept  POINT (-86.76218008309999 36.1724554062)           15
# 111  Health Dept      POINT (-86.7603189731 36.1722220733)           15
# 393        Civic      POINT (-86.7587196799 36.1740162738)           15
# 394        Civic  POINT (-86.76031268049999 36.1722879774)           15
# 395        Civic      POINT (-86.7602654582 36.1722096836)           15
#
#                    name
# 4    Historic Edgefield
# 111  Historic Edgefield
# 393  Historic Edgefield
# 394  Historic Edgefield
# 395  Historic Edgefield

# %%
# join MTA stops with neighborhoods
nash_busses = gpd.sjoin(mta_stops_geo, neighborhoods, op = 'within')
nash_busses.head()
# Out:
#     Stop_ID_Number Stop_Abbreviation                         Stop_Name  \
# 7              463          BRAWEDNN  BRANSFORD AVE & WEDGEWOOD AVE NB
# 15             228           5ACOMNN        5TH AVE N & COMMERCE ST NB
# 16             226          5AVCHUNN          5TH AVE N & CHURCH ST NB
# 17             224          5AVCHUNM         5TH AVE N & THE ARCADE NB
# 18             243          6AVCHUSN          6TH AVE N & CHURCH ST SB
#
#     Shelter  Bench  Route_Number Route_Name        Lng        Lat  \
# 7         0      0             1  VINE HILL -86.768817  36.132468
# 15        0      0             1  VINE HILL -86.779169  36.161732
# 16        1      1             1  VINE HILL -86.780078  36.163054
# 17        0      0             1  VINE HILL -86.780627  36.163938
# 18        0      0             1  VINE HILL -86.781601  36.162833
#
#                               Mapped_Loc  \
# 7           POINT (-86.768817 36.132468)
# 15          POINT (-86.779169 36.161732)
# 16          POINT (-86.780078 36.163054)
# 17          POINT (-86.780627 36.163938)
# 18  POINT (-86.78160099999999 36.162833)
#
#                                 geometry  index_right              name
# 7           POINT (-86.768817 36.132468)          114  Bransford Avenue
# 15          POINT (-86.779169 36.161732)           41   Urban Residents
# 16          POINT (-86.780078 36.163054)           41   Urban Residents
# 17          POINT (-86.780627 36.163938)           41   Urban Residents
# 18  POINT (-86.78160099999999 36.162833)           41   Urban Residents

# %%
# get the quantity of bike rack stations within each neighborhood
nash_bikes[['name','IDNumber']].groupby('name').agg('count').sort_values(by='IDNumber', ascending=False)
# Out:
#                               IDNumber
# name
# Urban Residents                     51
# Sylvan Park                         10
# Hillsboro-West End                   9
# Woodbine                             6
# Edgehill (ONE)                       6
# Nations                              6
# Lockeland Springs                    6
# Historic Edgefield                   5
# Sunnyside                            4
# Glencliff                            4
# Germantown                           4
# Bordeaux                             4
# Eastwood                             3
# Capitol View                         3
# Historic Buena Vista                 3
# Inglewood                            3
# Buena Vista                          2
# Chestnut Hill (TAG)                  2
# Shelby Hills                         2
# Rosebank                             2
# Priest Lake Meadows                  2
# Neighbors of Antioch                 2
# Napier Area                          2
# McFerrin Park                        2
# Maxwell Heights                      2
# Jackson Park                         2
# Greenwood                            2
# Hillwood                             2
# Highland Heights                     2
# Historic Old Hickory Village         2
# Crieve Hall                          1
# Whites Creek                         1
# White Bridge                         1
# West Meade Park                      1
# Wedgewood Houston (SNAP)             1
# Gra-Mar Acres                        1
# Una                                  1
# Charlotte Park                       1
# Sylvan Heights                       1
# Hermitage Hills                      1
# South Inglewood (CCSI)               1
# Hillbrook                            1
# Parkwood Estates                     1
# Osage                                1
# East End                             1
# Neighbors Reaching Out               1
# East Thompson Community              1
# McMurray-Huntingdon                  1
# Cumberland Gardens                   1
# Cleveland Park                       1

# %%
# get the quantity of bus stops within each neighborhood
nash_busses[['name','Stop_ID_Number']].groupby('name').agg('count').sort_values(by='Stop_ID_Number', ascending=False)
# Out:
#                               Stop_ID_Number
# name
# Urban Residents                          160
# Highland Heights                          43
# Bordeaux                                  32
# Sunnyside                                 32
# Edgehill (ONE)                            30
# Lockeland Springs                         30
# South Inglewood (CCSI)                    26
# Capitol View                              23
# Maxwell Heights                           21
# Belmont-Hillsboro                         21
# Parkwood Estates                          20
# Porter Heights                            18
# McFerrin Park                             14
# Bordeaux Hills-River Meadows              13
# Rosebank                                  13
# Inglewood                                 12
# Priest Lake Meadows                       12
# Eastwood                                  12
# Battlemont                                11
# Neighbors Reaching Out                    11
# Historic Edgefield                         9
# Avalon                                     9
# Village by the Creek                       8
# Buena Vista                                8
# Piccadilly Square                          7
# Haynes Manor                               7
# Chestnut Hill (TAG)                        7
# Nashboro Village                           7
# Germantown                                 6
# Priest Lake                                6
# ...                                      ...
# Napier Area                                5
# Tulip Grove                                5
# White Bridge                               5
# Caldwell-Abbay Hall                        5
# Charlotte Park                             4
# Wedgewood Houston (SNAP)                   4
# Hadley Park                                4
# Hillsboro-West End                         4
# Neighbors of Antioch                       4
# Nations                                    4
# River Plantation                           3
# Trinity Hills                              3
# Greenwood                                  3
# Rolling Acres                              3
# Pinnacle Point                             3
# River Plantation III                       2
# Castlegate                                 2
# Colemont                                   2
# Hillbrook                                  2
# Glencliff                                  2
# Waverly Place                              2
# Villages of Brentwood                      1
# Whitland Area                              1
# Oakland Acres                              1
# Hope Gardens                               1
# Bransford Avenue                           1
# Tomorrow's Hope                            1
# Fredericksburg                             1
# East End                                   1
# Woodland-in-Waverly                        1
#
# [66 rows x 1 columns]

# %%
urban_bikes = nash_bikes.loc[nash_bikes.name == 'Urban Residents']
urban_bikes.head()
# Out:
#                                         Geom  ID  Type  Domain  \
# 9       POINT (-86.7799546267 36.1633719897)  10  Rack  Public
# 10   POINT (-86.77974046940001 36.163455453)  11  Rack  Public
# 11  POINT (-86.78151617340001 36.1623498407)  12  Rack  Public
# 12      POINT (-86.7762348971 36.1632842775)  13  Rack  Public
# 13      POINT (-86.7760875556 36.1631394547)  14  Rack  Public
#
#              Status  IDNumber  Quantity  Location  Capacity        Lng  \
# 9   Future Artistic        83         0  Bus Stop         0 -86.779955
# 10         Existing        57         1  Bus Stop         2 -86.779740
# 11         Existing       119         2   Library         4 -86.781516
# 12         Proposed       258         0  Bus Stop         0 -86.776235
# 13  Future Artistic       259         0  Bus Stop         0 -86.776088
#
#           Lat                                             Detail    Data_Coll  \
# 9   36.163372  Bus Stop; Church St at 5th Ave N, Fifth Third ...  Health Dept
# 10  36.163455  Bus Stop; Church St at 5th Ave N, Fifth Third ...  Health Dept
# 11  36.162350                  Downtown Nashville Public Library  Health Dept
# 12  36.163284  Bus Stop; Commerce St at 2nd Ave N  -  2nd Ave...  Health Dept
# 13  36.163139  Bus Stop; Commerce St at 2nd Ave N  -  2nd Ave...  Health Dept
#
#                                     geometry  index_right             name
# 9       POINT (-86.7799546267 36.1633719897)           41  Urban Residents
# 10   POINT (-86.77974046940001 36.163455453)           41  Urban Residents
# 11  POINT (-86.78151617340001 36.1623498407)           41  Urban Residents
# 12      POINT (-86.7762348971 36.1632842775)           41  Urban Residents
# 13      POINT (-86.7760875556 36.1631394547)           41  Urban Residents

# %%
urban_polygon = neighborhoods.loc[neighborhoods.name == 'Urban Residents']
urban_polygon.head()
# Out:
#                name                                           geometry
# 41  Urban Residents  (POLYGON ((-86.78122053774267 36.1645653773768...

# %%
ax = urban_polygon.plot(figsize = (12, 12), color = 'lightgreen')
urban_bikes.plot( ax = ax, column = 'Status', legend = True);
plt.show();

# %%
urban_busses = nash_busses.loc[nash_busses.name == 'Urban Residents']
urban_busses.head()
# Out:
#     Stop_ID_Number Stop_Abbreviation                   Stop_Name  Shelter  \
# 15             228           5ACOMNN  5TH AVE N & COMMERCE ST NB        0
# 16             226          5AVCHUNN    5TH AVE N & CHURCH ST NB        1
# 17             224          5AVCHUNM   5TH AVE N & THE ARCADE NB        0
# 18             243          6AVCHUSN    6TH AVE N & CHURCH ST SB        0
# 19             702          6AVCOMSN  6TH AVE N & COMMERCE ST SB        0
#
#     Bench  Route_Number Route_Name        Lng        Lat  \
# 15      0             1  VINE HILL -86.779169  36.161732
# 16      1             1  VINE HILL -86.780078  36.163054
# 17      0             1  VINE HILL -86.780627  36.163938
# 18      0             1  VINE HILL -86.781601  36.162833
# 19      1             1  VINE HILL -86.780728  36.161447
#
#                               Mapped_Loc  \
# 15          POINT (-86.779169 36.161732)
# 16          POINT (-86.780078 36.163054)
# 17          POINT (-86.780627 36.163938)
# 18  POINT (-86.78160099999999 36.162833)
# 19          POINT (-86.780728 36.161447)
#
#                                 geometry  index_right             name
# 15          POINT (-86.779169 36.161732)           41  Urban Residents
# 16          POINT (-86.780078 36.163054)           41  Urban Residents
# 17          POINT (-86.780627 36.163938)           41  Urban Residents
# 18  POINT (-86.78160099999999 36.162833)           41  Urban Residents
# 19          POINT (-86.780728 36.161447)           41  Urban Residents

# %%
ax = urban_polygon.plot(figsize = (12, 12), color = 'lightgreen')
leg_kwds = {'title': 'Route Name', 'loc': 'upper left', 'bbox_to_anchor': (1, 1.01), 'ncol': 2}
urban_busses.plot( ax = ax, column = 'Route_Name', legend = True, legend_kwds = leg_kwds);
plt.show();

# %%
# find the center of urban polygon
center = urban_polygon.geometry.centroid
center
# Out:
# 41    POINT (-86.77756457127047 36.16127820928791)
# dtype: object

# %%
# get and store the first occurence
center_point = center.iloc[0]

# %%
# reverse the order for folium, since it wants latitude first and shapely Points have longitude first
urban_center = [center_point.y, center_point.x]
urban_center
# Out:
# [36.161278209287914, -86.77756457127047]

# %%
# create and show a map of downtown Nashville
downtown_map = folium.Map(location = urban_center, zoom_start = 15)
downtown_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for row in urban_bikes.iterrows():
    row_values = row[1]
    print(row_values)
# Out:
# Geom                        POINT (-86.7799546267 36.1633719897)
# ID                                                            10
# Type                                                        Rack
# Domain                                                    Public
# Status                                           Future Artistic
# IDNumber                                                      83
# Quantity                                                       0
# Location                                                Bus Stop
# Capacity                                                       0
# Lng                                                       -86.78
# Lat                                                      36.1634
# Detail         Bus Stop; Church St at 5th Ave N, Fifth Third ...
# Data_Coll                                            Health Dept
# geometry                    POINT (-86.7799546267 36.1633719897)
# index_right                                                   41
# name                                             Urban Residents
# Name: 9, dtype: object
# Geom                     POINT (-86.77974046940001 36.163455453)
# ID                                                            11
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                      57
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       2
# Lng                                                     -86.7797
# Lat                                                      36.1635
# Detail         Bus Stop; Church St at 5th Ave N, Fifth Third ...
# Data_Coll                                            Health Dept
# geometry                 POINT (-86.77974046940001 36.163455453)
# index_right                                                   41
# name                                             Urban Residents
# Name: 10, dtype: object
# Geom           POINT (-86.78151617340001 36.1623498407)
# ID                                                   12
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                            119
# Quantity                                              2
# Location                                        Library
# Capacity                                              4
# Lng                                            -86.7815
# Lat                                             36.1623
# Detail                Downtown Nashville Public Library
# Data_Coll                                   Health Dept
# geometry       POINT (-86.78151617340001 36.1623498407)
# index_right                                          41
# name                                    Urban Residents
# Name: 11, dtype: object
# Geom                        POINT (-86.7762348971 36.1632842775)
# ID                                                            13
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Proposed
# IDNumber                                                     258
# Quantity                                                       0
# Location                                                Bus Stop
# Capacity                                                       0
# Lng                                                     -86.7762
# Lat                                                      36.1633
# Detail         Bus Stop; Commerce St at 2nd Ave N  -  2nd Ave...
# Data_Coll                                            Health Dept
# geometry                    POINT (-86.7762348971 36.1632842775)
# index_right                                                   41
# name                                             Urban Residents
# Name: 12, dtype: object
# Geom                        POINT (-86.7760875556 36.1631394547)
# ID                                                            14
# Type                                                        Rack
# Domain                                                    Public
# Status                                           Future Artistic
# IDNumber                                                     259
# Quantity                                                       0
# Location                                                Bus Stop
# Capacity                                                       0
# Lng                                                     -86.7761
# Lat                                                      36.1631
# Detail         Bus Stop; Commerce St at 2nd Ave N  -  2nd Ave...
# Data_Coll                                            Health Dept
# geometry                    POINT (-86.7760875556 36.1631394547)
# index_right                                                   41
# name                                             Urban Residents
# Name: 13, dtype: object
# Geom           POINT (-86.78147500040001 36.1594361108)
# ID                                                   21
# Type                                               Rack
# Domain                                           Public
# Status                                         Proposed
# IDNumber                                            265
# Quantity                                              0
# Location                                    High School
# Capacity                                              0
# Lng                                            -86.7815
# Lat                                             36.1594
# Detail            Hume-Fogg Academic Magnet High School
# Data_Coll                                   Health Dept
# geometry       POINT (-86.78147500040001 36.1594361108)
# index_right                                          41
# name                                    Urban Residents
# Name: 20, dtype: object
# Geom           POINT (-86.77373741059999 36.1598191975)
# ID                                                   24
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                            120
# Quantity                                              2
# Location                                       Bus Stop
# Capacity                                              4
# Lng                                            -86.7737
# Lat                                             36.1598
# Detail             Bus Stop; Demonbreun St at 2nd Ave S
# Data_Coll                                   Health Dept
# geometry       POINT (-86.77373741059999 36.1598191975)
# index_right                                          41
# name                                    Urban Residents
# Name: 23, dtype: object
# Geom           POINT (-86.77390733870001 36.1598055749)
# ID                                                   25
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                            121
# Quantity                                              2
# Location                                       Bus Stop
# Capacity                                              4
# Lng                                            -86.7739
# Lat                                             36.1598
# Detail             Bus Stop; Demonbreun St at 2nd Ave S
# Data_Coll                                   Health Dept
# geometry       POINT (-86.77390733870001 36.1598055749)
# index_right                                          41
# name                                    Urban Residents
# Name: 24, dtype: object
# Geom           POINT (-86.77705027370001 36.1586563645)
# ID                                                  282
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                            245
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              8
# Lng                                            -86.7771
# Lat                                             36.1587
# Detail             Bus Stop; Demonbreun St at 5th Ave S
# Data_Coll                                   Health Dept
# geometry       POINT (-86.77705027370001 36.1586563645)
# index_right                                          41
# name                                    Urban Residents
# Name: 281, dtype: object
# Geom           POINT (-86.7771462844 36.1587184747)
# ID                                              283
# Type                                           Rack
# Domain                                       Public
# Status                                     Proposed
# IDNumber                                        384
# Quantity                                          0
# Location                                   Bus Stop
# Capacity                                          0
# Lng                                        -86.7771
# Lat                                         36.1587
# Detail         Bus Stop; Demonbreun St at 5th Ave S
# Data_Coll                               Health Dept
# geometry       POINT (-86.7771462844 36.1587184747)
# index_right                                      41
# name                                Urban Residents
# Name: 282, dtype: object
# Geom           POINT (-86.78172986620001 36.1593378827)
# ID                                                  284
# Type                                               Rack
# Domain                                           Public
# Status                                         Proposed
# IDNumber                                            344
# Quantity                                              0
# Location                                    High School
# Capacity                                              0
# Lng                                            -86.7817
# Lat                                             36.1593
# Detail            Hume-Fogg Academic Magnet High School
# Data_Coll                                   Health Dept
# geometry       POINT (-86.78172986620001 36.1593378827)
# index_right                                          41
# name                                    Urban Residents
# Name: 283, dtype: object
# Geom            POINT (-86.7820023032 36.1592323869)
# ID                                               285
# Type                                            Rack
# Domain                                        Public
# Status                                      Proposed
# IDNumber                                         345
# Quantity                                           0
# Location                                 High School
# Capacity                                           0
# Lng                                          -86.782
# Lat                                          36.1592
# Detail         Hume-Fogg Academic Magnet High School
# Data_Coll                                Health Dept
# geometry        POINT (-86.7820023032 36.1592323869)
# index_right                                       41
# name                                 Urban Residents
# Name: 284, dtype: object
# Geom           POINT (-86.77566666700001 36.1592611113)
# ID                                                  290
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             11
# Quantity                                              1
# Location                              Downtown Building
# Capacity                                             20
# Lng                                            -86.7757
# Lat                                             36.1593
# Detail                     Schermerhorn Symphony Center
# Data_Coll                                         Civic
# geometry       POINT (-86.77566666700001 36.1592611113)
# index_right                                          41
# name                                    Urban Residents
# Name: 289, dtype: object
# Geom           POINT (-86.77716944469999 36.1587444444)
# ID                                                  291
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             12
# Quantity                                              1
# Location                                           Park
# Capacity                                              5
# Lng                                            -86.7772
# Lat                                             36.1587
# Detail                           Nashville Music Garden
# Data_Coll                                         Civic
# geometry       POINT (-86.77716944469999 36.1587444444)
# index_right                                          41
# name                                    Urban Residents
# Name: 290, dtype: object
# Geom                    POINT (-86.77309046559999 36.1579856882)
# ID                                                           299
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       5
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       6
# Lng                                                     -86.7731
# Lat                                                       36.158
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                POINT (-86.77309046559999 36.1579856882)
# index_right                                                   41
# name                                             Urban Residents
# Name: 298, dtype: object
# Geom                    POINT (-86.77401111110001 36.1575944443)
# ID                                                           300
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       4
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       6
# Lng                                                      -86.774
# Lat                                                      36.1576
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                POINT (-86.77401111110001 36.1575944443)
# index_right                                                   41
# name                                             Urban Residents
# Name: 299, dtype: object
# Geom                     POINT (-86.77383463930001 36.157286844)
# ID                                                           301
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       3
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       6
# Lng                                                     -86.7738
# Lat                                                      36.1573
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                 POINT (-86.77383463930001 36.157286844)
# index_right                                                   41
# name                                             Urban Residents
# Name: 300, dtype: object
# Geom                        POINT (-86.7729303238 36.1576634751)
# ID                                                           302
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       2
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       4
# Lng                                                     -86.7729
# Lat                                                      36.1577
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                    POINT (-86.7729303238 36.1576634751)
# index_right                                                   41
# name                                             Urban Residents
# Name: 301, dtype: object
# Geom                        POINT (-86.7721587612 36.1579960558)
# ID                                                           303
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       1
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       4
# Lng                                                     -86.7722
# Lat                                                       36.158
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                    POINT (-86.7721587612 36.1579960558)
# index_right                                                   41
# name                                             Urban Residents
# Name: 302, dtype: object
# Geom                    POINT (-86.77233498780001 36.1583047731)
# ID                                                           304
# Type                                                        Rack
# Domain                                                    Public
# Status                                                  Existing
# IDNumber                                                       6
# Quantity                                                       1
# Location                                                Bus Stop
# Capacity                                                       4
# Lng                                                     -86.7723
# Lat                                                      36.1583
# Detail         Bus Stop; Korean Veterans Blvd between 1st Ave...
# Data_Coll                                                  Civic
# geometry                POINT (-86.77233498780001 36.1583047731)
# index_right                                                   41
# name                                             Urban Residents
# Name: 303, dtype: object
# Geom           POINT (-86.77660833379998 36.1597611112)
# ID                                                  307
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             13
# Quantity                                              1
# Location                                           Park
# Capacity                                              5
# Lng                                            -86.7766
# Lat                                             36.1598
# Detail                           Nashville Music Garden
# Data_Coll                                         Civic
# geometry       POINT (-86.77660833379998 36.1597611112)
# index_right                                          41
# name                                    Urban Residents
# Name: 306, dtype: object
# Geom           POINT (-86.78189926479999 36.1660203215)
# ID                                                  308
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             29
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7819
# Lat                                              36.166
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry       POINT (-86.78189926479999 36.1660203215)
# index_right                                          41
# name                                    Urban Residents
# Name: 307, dtype: object
# Geom               POINT (-86.7817488363 36.1659996763)
# ID                                                  309
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             30
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7817
# Lat                                              36.166
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry           POINT (-86.7817488363 36.1659996763)
# index_right                                          41
# name                                    Urban Residents
# Name: 308, dtype: object
# Geom            POINT (-86.78136668040001 36.166157226)
# ID                                                  310
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             31
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7814
# Lat                                             36.1662
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry        POINT (-86.78136668040001 36.166157226)
# index_right                                          41
# name                                    Urban Residents
# Name: 309, dtype: object
# Geom               POINT (-86.7810912182 36.1662872767)
# ID                                                  311
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             32
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7811
# Lat                                             36.1663
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry           POINT (-86.7810912182 36.1662872767)
# index_right                                          41
# name                                    Urban Residents
# Name: 310, dtype: object
# Geom                POINT (-86.7808803631 36.166388699)
# ID                                                  312
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             33
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7809
# Lat                                             36.1664
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry            POINT (-86.7808803631 36.166388699)
# index_right                                          41
# name                                    Urban Residents
# Name: 311, dtype: object
# Geom           POINT (-86.78223333299999 36.1667166664)
# ID                                                  313
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             34
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7822
# Lat                                             36.1667
# Detail         Downtown Bus Station; Music City Central
# Data_Coll                                         Civic
# geometry       POINT (-86.78223333299999 36.1667166664)
# index_right                                          41
# name                                    Urban Residents
# Name: 312, dtype: object
# Geom           POINT (-86.77997381889999 36.16146803260001)
# ID                                                      315
# Type                                                   Rack
# Domain                                               Public
# Status                                             Existing
# IDNumber                                                 15
# Quantity                                                  1
# Location                                  Convention Center
# Capacity                                                  2
# Lng                                                  -86.78
# Lat                                                 36.1615
# Detail                          Nashville Convention Center
# Data_Coll                                             Civic
# geometry       POINT (-86.77997381889999 36.16146803260001)
# index_right                                              41
# name                                        Urban Residents
# Name: 314, dtype: object
# Geom           POINT (-86.78018034959999 36.1613764454)
# ID                                                  316
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             16
# Quantity                                              1
# Location                              Convention Center
# Capacity                                              2
# Lng                                            -86.7802
# Lat                                             36.1614
# Detail                      Nashville Convention Center
# Data_Coll                                         Civic
# geometry       POINT (-86.78018034959999 36.1613764454)
# index_right                                          41
# name                                    Urban Residents
# Name: 315, dtype: object
# Geom           POINT (-86.782276411 36.1621328629)
# ID                                             318
# Type                                          Rack
# Domain                                      Public
# Status                                    Existing
# IDNumber                                        18
# Quantity                                         1
# Location                                   Library
# Capacity                                         4
# Lng                                       -86.7823
# Lat                                        36.1621
# Detail           Downtown Nashville Public Library
# Data_Coll                                    Civic
# geometry       POINT (-86.782276411 36.1621328629)
# index_right                                     41
# name                               Urban Residents
# Name: 317, dtype: object
# Geom           POINT (-86.7816977919 36.1623921112)
# ID                                              319
# Type                                           Rack
# Domain                                       Public
# Status                                     Existing
# IDNumber                                         19
# Quantity                                          1
# Location                                    Library
# Capacity                                          4
# Lng                                        -86.7817
# Lat                                         36.1624
# Detail            Downtown Nashville Public Library
# Data_Coll                                     Civic
# geometry       POINT (-86.7816977919 36.1623921112)
# index_right                                      41
# name                                Urban Residents
# Name: 318, dtype: object
# Geom           POINT (-86.7823587076 36.1630799308)
# ID                                              320
# Type                                           Rack
# Domain                                       Public
# Status                                     Existing
# IDNumber                                         21
# Quantity                                          1
# Location                                   Bus Stop
# Capacity                                          2
# Lng                                        -86.7824
# Lat                                         36.1631
# Detail             Bus Stop; Church St at 6th Ave N
# Data_Coll                                     Civic
# geometry       POINT (-86.7823587076 36.1630799308)
# index_right                                      41
# name                                Urban Residents
# Name: 319, dtype: object
# Geom           POINT (-86.77782399860001 36.164280456)
# ID                                                 321
# Type                                              Rack
# Domain                                          Public
# Status                                        Existing
# IDNumber                                            22
# Quantity                                             1
# Location                                      Bus Stop
# Capacity                                             2
# Lng                                           -86.7778
# Lat                                            36.1643
# Detail                Bus Stop; Church St at 3rd Ave N
# Data_Coll                                        Civic
# geometry       POINT (-86.77782399860001 36.164280456)
# index_right                                         41
# name                                   Urban Residents
# Name: 320, dtype: object
# Geom           POINT (-86.7770277779 36.1645916666)
# ID                                              322
# Type                                           Rack
# Domain                                       Public
# Status                                     Existing
# IDNumber                                         23
# Quantity                                          1
# Location                                   Bus Stop
# Capacity                                          2
# Lng                                         -86.777
# Lat                                         36.1646
# Detail             Bus Stop; Church St at 2nd Ave N
# Data_Coll                                     Civic
# geometry       POINT (-86.7770277779 36.1645916666)
# index_right                                      41
# name                                Urban Residents
# Name: 321, dtype: object
# Geom           POINT (-86.7821974303 36.1628172178)
# ID                                              323
# Type                                           Rack
# Domain                                       Public
# Status                                     Existing
# IDNumber                                         20
# Quantity                                          1
# Location                                   Bus Stop
# Capacity                                          2
# Lng                                        -86.7822
# Lat                                         36.1628
# Detail             Bus Stop; Church St at 6th Ave N
# Data_Coll                                     Civic
# geometry       POINT (-86.7821974303 36.1628172178)
# index_right                                      41
# name                                Urban Residents
# Name: 322, dtype: object
# Geom                    POINT (-86.7812937082 36.1652715951)
# ID                                                       331
# Type                                                    Rack
# Domain                                                Public
# Status                                              Existing
# IDNumber                                                  40
# Quantity                                                   1
# Location                                            Bus Stop
# Capacity                                                   2
# Lng                                                 -86.7813
# Lat                                                  36.1653
# Detail         Bus Stop; Deadrick St- 3rd Ave N to 6th Ave N
# Data_Coll                                              Civic
# geometry                POINT (-86.7812937082 36.1652715951)
# index_right                                               41
# name                                         Urban Residents
# Name: 330, dtype: object
# Geom            POINT (-86.78134343790001 36.16548003320001)
# ID                                                       332
# Type                                                    Rack
# Domain                                                Public
# Status                                              Existing
# IDNumber                                                  39
# Quantity                                                   1
# Location                                            Bus Stop
# Capacity                                                   2
# Lng                                                 -86.7813
# Lat                                                  36.1655
# Detail         Bus Stop; Deadrick St- 3rd Ave N to 6th Ave N
# Data_Coll                                              Civic
# geometry        POINT (-86.78134343790001 36.16548003320001)
# index_right                                               41
# name                                         Urban Residents
# Name: 331, dtype: object
# Geom                    POINT (-86.7806146768 36.1655504694)
# ID                                                       333
# Type                                                    Rack
# Domain                                                Public
# Status                                              Existing
# IDNumber                                                  42
# Quantity                                                   1
# Location                                            Bus Stop
# Capacity                                                   2
# Lng                                                 -86.7806
# Lat                                                  36.1656
# Detail         Bus Stop; Deadrick St- 3rd Ave N to 6th Ave N
# Data_Coll                                              Civic
# geometry                POINT (-86.7806146768 36.1655504694)
# index_right                                               41
# name                                         Urban Residents
# Name: 332, dtype: object
# Geom                    POINT (-86.7805896002 36.1657975738)
# ID                                                       334
# Type                                                    Rack
# Domain                                                Public
# Status                                              Existing
# IDNumber                                                  41
# Quantity                                                   1
# Location                                            Bus Stop
# Capacity                                                   2
# Lng                                                 -86.7806
# Lat                                                  36.1658
# Detail         Bus Stop; Deadrick St- 3rd Ave N to 6th Ave N
# Data_Coll                                              Civic
# geometry                POINT (-86.7805896002 36.1657975738)
# index_right                                               41
# name                                         Urban Residents
# Name: 333, dtype: object
# Geom           POINT (-86.78139852450001 36.1613586838)
# ID                                                  336
# Type                                            Covered
# Domain                                           Public
# Status                                         Existing
# IDNumber                                            108
# Quantity                                              1
# Location                                        Library
# Capacity                                              8
# Lng                                            -86.7814
# Lat                                             36.1614
# Detail           Downtown Public Library Parking Garage
# Data_Coll                                         Civic
# geometry       POINT (-86.78139852450001 36.1613586838)
# index_right                                          41
# name                                    Urban Residents
# Name: 335, dtype: object
# Geom           POINT (-86.78114728930001 36.1614371245)
# ID                                                  338
# Type                                             Locker
# Domain                                           Public
# Status                                         Proposed
# IDNumber                                            251
# Quantity                                              0
# Location                                        Library
# Capacity                                              0
# Lng                                            -86.7811
# Lat                                             36.1614
# Detail                Downtown Nashville Public Library
# Data_Coll                                         Civic
# geometry       POINT (-86.78114728930001 36.1614371245)
# index_right                                          41
# name                                    Urban Residents
# Name: 337, dtype: object
# Geom           POINT (-86.77952283709999 36.1633101142)
# ID                                                  346
# Type                                            Covered
# Domain                                          Private
# Status                                         Existing
# IDNumber                                            111
# Quantity                                              1
# Location                            Residential Complex
# Capacity                                              2
# Lng                                            -86.7795
# Lat                                             36.1633
# Detail                                   Viridian tower
# Data_Coll                                         Civic
# geometry       POINT (-86.77952283709999 36.1633101142)
# index_right                                          41
# name                                    Urban Residents
# Name: 345, dtype: object
# Geom           POINT (-86.78194863580001 36.1625350715)
# ID                                                  354
# Type                                           Artistic
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             64
# Quantity                                              2
# Location                                           Park
# Capacity                                              4
# Lng                                            -86.7819
# Lat                                             36.1625
# Detail                               Church Street Park
# Data_Coll                                         Civic
# geometry       POINT (-86.78194863580001 36.1625350715)
# index_right                                          41
# name                                    Urban Residents
# Name: 353, dtype: object
# Geom           POINT (-86.77897952709999 36.1618806306)
# ID                                                  355
# Type                                           Artistic
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             63
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                             10
# Lng                                             -86.779
# Lat                                             36.1619
# Detail           Bus Stop; 401 Commerce St at 5th Ave N
# Data_Coll                                         Civic
# geometry       POINT (-86.77897952709999 36.1618806306)
# index_right                                          41
# name                                    Urban Residents
# Name: 354, dtype: object
# Geom           POINT (-86.7783275876 36.1621360882)
# ID                                              356
# Type                                           Rack
# Domain                                       Public
# Status                                     Proposed
# IDNumber                                         61
# Quantity                                          0
# Location                                       Park
# Capacity                                          0
# Lng                                        -86.7783
# Lat                                         36.1621
# Detail           Bi-Centennial Mall, Farmers Market
# Data_Coll                                     Civic
# geometry       POINT (-86.7783275876 36.1621360882)
# index_right                                      41
# name                                Urban Residents
# Name: 355, dtype: object
# Geom           POINT (-86.7741142536 36.1601280975)
# ID                                              357
# Type                                           Rack
# Domain                                       Public
# Status                                     Existing
# IDNumber                                         52
# Quantity                                          1
# Location                          Downtown Building
# Capacity                                          8
# Lng                                        -86.7741
# Lat                                         36.1601
# Detail                        The Pinnacle Building
# Data_Coll                                     Civic
# geometry       POINT (-86.7741142536 36.1601280975)
# index_right                                      41
# name                                Urban Residents
# Name: 356, dtype: object
# Geom           POINT (-86.77439911129999 36.1597536941)
# ID                                                  361
# Type                                               Rack
# Domain                                           Public
# Status                                         Existing
# IDNumber                                             53
# Quantity                                              1
# Location                                       Bus Stop
# Capacity                                              2
# Lng                                            -86.7744
# Lat                                             36.1598
# Detail                                Pinnacle Building
# Data_Coll                                         Civic
# geometry       POINT (-86.77439911129999 36.1597536941)
# index_right                                          41
# name                                    Urban Residents
# Name: 360, dtype: object
# Geom           POINT (-86.77428720030001 36.1609749314)
# ID                                                  376
# Type                                               Rack
# Domain                                           Public
# Status                                         Proposed
# IDNumber                                             80
# Quantity                                              0
# Location                                       Greenway
# Capacity                                              0
# Lng                                            -86.7743
# Lat                                              36.161
# Detail                                Downtown Greenway
# Data_Coll                                         Civic
# geometry       POINT (-86.77428720030001 36.1609749314)
# index_right                                          41
# name                                    Urban Residents
# Name: 375, dtype: object
# Geom                    POINT (-86.77595644290001 36.1632396852)
# ID                                                           377
# Type                                                        Rack
# Domain                                                    Public
# Status                                           Future Artistic
# IDNumber                                                      82
# Quantity                                                       0
# Location                                                Bus Stop
# Capacity                                                       0
# Lng                                                      -86.776
# Lat                                                      36.1632
# Detail         Commerce St and 2nd Ave N  -  2nd Ave N adjace...
# Data_Coll                                                  Civic
# geometry                POINT (-86.77595644290001 36.1632396852)
# index_right                                                   41
# name                                             Urban Residents
# Name: 376, dtype: object
# Geom           POINT (-86.77936035340001 36.1636023393)
# ID                                                  378
# Type                                               Rack
# Domain                                           Public
# Status                                         Proposed
# IDNumber                                             84
# Quantity                                              0
# Location                                       Bus Stop
# Capacity                                              0
# Lng                                            -86.7794
# Lat                                             36.1636
# Detail                           Church St ad 4th Ave N
# Data_Coll                                         Civic
# geometry       POINT (-86.77936035340001 36.1636023393)
# index_right                                          41
# name                                    Urban Residents
# Name: 377, dtype: object
# Geom           POINT (-86.77438767299999 36.1608659758)
# ID                                                  411
# Type                                               Rack
# Domain                                           Public
# Status                                  Future Artistic
# IDNumber                                            432
# Quantity                                              0
# Location                                           Park
# Capacity                                              0
# Lng                                            -86.7744
# Lat                                             36.1609
# Detail                           Under Shelby St Bridge
# Data_Coll                                         Civic
# geometry       POINT (-86.77438767299999 36.1608659758)
# index_right                                          41
# name                                    Urban Residents
# Name: 410, dtype: object

# %%
# draw neighborhood
# folium.GeoJson(urban_polygon).add_to(downtown_map)

# iterate through urban bikes and create locations and markers
# note that latitude must come first for folium map to work
# for row in urban_bikes.iterrows():
#     row_values = row[1]
#     location = [row_values['Lat'], row_values['Lng']]
#     popup = (str(row_values['IDNumber']) + ': ' +
#              str(row_values['Status']) + '<br/>' +
#              'Quantity: ' + str(row_values['Quantity']) + '<br/>' +
#              str(row_values['Detail'])).replace("'", "`")
#     marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color='blue', icon='bicycle',
#                                                                                icon_color='white', prefix='fa'))
    
#     marker.add_to(downtown_map)

# # display map
# downtown_map

# %%
for row in urban_busses.iterrows():
    row_values = row[1]
    print(row_values)
# Out:
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    1
# Route_Name                              VINE HILL
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 15, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    1
# Route_Name                              VINE HILL
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 16, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    1
# Route_Name                              VINE HILL
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 17, dtype: object
# Stop_ID_Number                                        243
# Stop_Abbreviation                                6AVCHUSN
# Stop_Name                        6TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                            1
# Route_Name                                      VINE HILL
# Lng                                              -86.7816
# Lat                                               36.1628
# Mapped_Loc           POINT (-86.78160099999999 36.162833)
# geometry             POINT (-86.78160099999999 36.162833)
# index_right                                            41
# name                                      Urban Residents
# Name: 18, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    1
# Route_Name                              VINE HILL
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 19, dtype: object
# Stop_ID_Number                                        243
# Stop_Abbreviation                                6AVCHUSN
# Stop_Name                        6TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                            2
# Route_Name                                        BELMONT
# Lng                                              -86.7816
# Lat                                               36.1628
# Mapped_Loc           POINT (-86.78160099999999 36.162833)
# geometry             POINT (-86.78160099999999 36.162833)
# index_right                                            41
# name                                      Urban Residents
# Name: 33, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 34, dtype: object
# Stop_ID_Number                                265
# Stop_Abbreviation                         8ABROSN
# Stop_Name             8TH AVE S & BROADWAY AVE SB
# Shelter                                         1
# Bench                                           0
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7822
# Lat                                        36.159
# Mapped_Loc           POINT (-86.782225 36.159008)
# geometry             POINT (-86.782225 36.159008)
# index_right                                    41
# name                              Urban Residents
# Name: 35, dtype: object
# Stop_ID_Number                                263
# Stop_Abbreviation                         8ABRONM
# Stop_Name             8TH AVE S & BROADWAY AVE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7826
# Lat                                       36.1597
# Mapped_Loc           POINT (-86.782557 36.159688)
# geometry             POINT (-86.782557 36.159688)
# index_right                                    41
# name                              Urban Residents
# Name: 107, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 110, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 111, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    2
# Route_Name                                BELMONT
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 112, dtype: object
# Stop_ID_Number                                        243
# Stop_Abbreviation                                6AVCHUSN
# Stop_Name                        6TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                            3
# Route_Name                                       WEST END
# Lng                                              -86.7816
# Lat                                               36.1628
# Mapped_Loc           POINT (-86.78160099999999 36.162833)
# geometry             POINT (-86.78160099999999 36.162833)
# index_right                                            41
# name                                      Urban Residents
# Name: 118, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    3
# Route_Name                               WEST END
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 119, dtype: object
# Stop_ID_Number                               3850
# Stop_Abbreviation                         BRO2AWN
# Stop_Name             BROADWAY AVE & 2ND AVE N WB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7751
# Lat                                        36.162
# Mapped_Loc           POINT (-86.775075 36.161991)
# geometry             POINT (-86.775075 36.161991)
# index_right                                    41
# name                              Urban Residents
# Name: 433, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 434, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 435, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 436, dtype: object
# Stop_ID_Number                                       3862
# Stop_Abbreviation                                 COM5AWN
# Stop_Name                         COMMERCE ST & 5TH AVE N
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                            6
# Route_Name                                   LEBANON ROAD
# Lng                                              -86.7793
# Lat                                               36.1619
# Mapped_Loc           POINT (-86.77928100000001 36.161947)
# geometry             POINT (-86.77928100000001 36.161947)
# index_right                                            41
# name                                      Urban Residents
# Name: 437, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 438, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 439, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                            6
# Route_Name                                   LEBANON ROAD
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 440, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                            6
# Route_Name                                   LEBANON ROAD
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 441, dtype: object
# Stop_ID_Number                               506
# Stop_Abbreviation                        BRO2AEN
# Stop_Name            BROADWAY AVE & 2ND AVE S EB
# Shelter                                        0
# Bench                                          1
# Route_Number                                   6
# Route_Name                          LEBANON ROAD
# Lng                                     -86.7754
# Lat                                      36.1617
# Mapped_Loc           POINT (-86.775429 36.16173)
# geometry             POINT (-86.775429 36.16173)
# index_right                                   41
# name                             Urban Residents
# Name: 442, dtype: object
# Stop_ID_Number                               2721
# Stop_Abbreviation                        2AVBRONN
# Stop_Name             2ND AVE N & BROADWAY AVE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7751
# Lat                                       36.1618
# Mapped_Loc           POINT (-86.775075 36.161821)
# geometry             POINT (-86.775075 36.161821)
# index_right                                    41
# name                              Urban Residents
# Name: 443, dtype: object
# Stop_ID_Number                                        499
# Stop_Abbreviation                                 BRO1AEN
# Stop_Name                     BROADWAY AVE & 1ST AVE N EB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                            6
# Route_Name                                   LEBANON ROAD
# Lng                                              -86.7745
# Lat                                               36.1622
# Mapped_Loc           POINT (-86.77449200000001 36.162205)
# geometry             POINT (-86.77449200000001 36.162205)
# index_right                                            41
# name                                      Urban Residents
# Name: 444, dtype: object
# Stop_ID_Number                               4054
# Stop_Abbreviation                        1AVDEMSN
# Stop_Name            1ST AVE S & DEMONBREUN ST SB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    6
# Route_Name                           LEBANON ROAD
# Lng                                      -86.7733
# Lat                                       36.1603
# Mapped_Loc            POINT (-86.773258 36.16033)
# geometry              POINT (-86.773258 36.16033)
# index_right                                    41
# name                              Urban Residents
# Name: 445, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    7
# Route_Name                              HILLSBORO
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 589, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    7
# Route_Name                              HILLSBORO
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 590, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    7
# Route_Name                              HILLSBORO
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 591, dtype: object
# Stop_ID_Number                                        243
# Stop_Abbreviation                                6AVCHUSN
# Stop_Name                        6TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                            8
# Route_Name                               8TH AVENUE SOUTH
# Lng                                              -86.7816
# Lat                                               36.1628
# Mapped_Loc           POINT (-86.78160099999999 36.162833)
# geometry             POINT (-86.78160099999999 36.162833)
# index_right                                            41
# name                                      Urban Residents
# Name: 596, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    8
# Route_Name                       8TH AVENUE SOUTH
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 597, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    8
# Route_Name                       8TH AVENUE SOUTH
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 661, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                    8
# Route_Name                       8TH AVENUE SOUTH
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 662, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                    8
# Route_Name                       8TH AVENUE SOUTH
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 663, dtype: object
# Stop_ID_Number                               3869
# Stop_Abbreviation                         UNI5AWN
# Stop_Name                 UNION ST & 5TH AVE N WB
# Shelter                                         0
# Bench                                           1
# Route_Number                                    9
# Route_Name                            METROCENTER
# Lng                                       -86.781
# Lat                                       36.1647
# Mapped_Loc           POINT (-86.780997 36.164688)
# geometry             POINT (-86.780997 36.164688)
# index_right                                    41
# name                              Urban Residents
# Name: 716, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           12
# Route_Name                               NOLENSVILLE ROAD
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 800, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           12
# Route_Name                               NOLENSVILLE ROAD
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 801, dtype: object
# Stop_ID_Number                               209
# Stop_Abbreviation                       4AVBROSM
# Stop_Name            4TH AVE S & BROADWAY AVE SB
# Shelter                                        0
# Bench                                          1
# Route_Number                                  12
# Route_Name                      NOLENSVILLE ROAD
# Lng                                     -86.7766
# Lat                                      36.1601
# Mapped_Loc           POINT (-86.776567 36.16008)
# geometry             POINT (-86.776567 36.16008)
# index_right                                   41
# name                             Urban Residents
# Name: 802, dtype: object
# Stop_ID_Number                                        185
# Stop_Abbreviation                                NXIPBODY
# Stop_Name                         PEABODY STATION INBOUND
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           12
# Route_Name                               NOLENSVILLE ROAD
# Lng                                              -86.7716
# Lat                                               36.1565
# Mapped_Loc           POINT (-86.77159899999999 36.156464)
# geometry             POINT (-86.77159899999999 36.156464)
# index_right                                            41
# name                                      Urban Residents
# Name: 899, dtype: object
# Stop_ID_Number                               2721
# Stop_Abbreviation                        2AVBRONN
# Stop_Name             2ND AVE N & BROADWAY AVE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   12
# Route_Name                       NOLENSVILLE ROAD
# Lng                                      -86.7751
# Lat                                       36.1618
# Mapped_Loc           POINT (-86.775075 36.161821)
# geometry             POINT (-86.775075 36.161821)
# index_right                                    41
# name                              Urban Residents
# Name: 900, dtype: object
# Stop_ID_Number                                       2722
# Stop_Abbreviation                                2AVCOMNN
# Stop_Name                      2ND AVE N & COMMERCE ST NB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                           12
# Route_Name                               NOLENSVILLE ROAD
# Lng                                               -86.776
# Lat                                               36.1632
# Mapped_Loc           POINT (-86.77599499999999 36.163214)
# geometry             POINT (-86.77599499999999 36.163214)
# index_right                                            41
# name                                      Urban Residents
# Name: 901, dtype: object
# Stop_ID_Number                               2723
# Stop_Abbreviation                        2AVCHUNN
# Stop_Name                2ND AVE N & CHURCH ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   12
# Route_Name                       NOLENSVILLE ROAD
# Lng                                      -86.7768
# Lat                                       36.1645
# Mapped_Loc           POINT (-86.776836 36.164545)
# geometry             POINT (-86.776836 36.164545)
# index_right                                    41
# name                              Urban Residents
# Name: 902, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   12
# Route_Name                       NOLENSVILLE ROAD
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 905, dtype: object
# Stop_ID_Number                                191
# Stop_Abbreviation                        3AVCHUNN
# Stop_Name                3RD AVE N & CHURCH ST NB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   12
# Route_Name                       NOLENSVILLE ROAD
# Lng                                      -86.7776
# Lat                                       36.1642
# Mapped_Loc           POINT (-86.777576 36.164179)
# geometry             POINT (-86.777576 36.164179)
# index_right                                    41
# name                              Urban Residents
# Name: 906, dtype: object
# Stop_ID_Number                               3869
# Stop_Abbreviation                         UNI5AWN
# Stop_Name                 UNION ST & 5TH AVE N WB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   12
# Route_Name                       NOLENSVILLE ROAD
# Lng                                       -86.781
# Lat                                       36.1647
# Mapped_Loc           POINT (-86.780997 36.164688)
# geometry             POINT (-86.780997 36.164688)
# index_right                                    41
# name                              Urban Residents
# Name: 909, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           15
# Route_Name                              MURFREESBORO ROAD
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 1017, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           15
# Route_Name                              MURFREESBORO ROAD
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 1018, dtype: object
# Stop_ID_Number                               209
# Stop_Abbreviation                       4AVBROSM
# Stop_Name            4TH AVE S & BROADWAY AVE SB
# Shelter                                        0
# Bench                                          1
# Route_Number                                  15
# Route_Name                     MURFREESBORO ROAD
# Lng                                     -86.7766
# Lat                                      36.1601
# Mapped_Loc           POINT (-86.776567 36.16008)
# geometry             POINT (-86.776567 36.16008)
# index_right                                   41
# name                             Urban Residents
# Name: 1019, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   15
# Route_Name                      MURFREESBORO ROAD
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 1117, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                   15
# Route_Name                      MURFREESBORO ROAD
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 1118, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   15
# Route_Name                      MURFREESBORO ROAD
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 1119, dtype: object
# Stop_ID_Number                               3850
# Stop_Abbreviation                         BRO2AWN
# Stop_Name             BROADWAY AVE & 2ND AVE N WB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   16
# Route_Name                  OLD HICKORY - MADISON
# Lng                                      -86.7751
# Lat                                        36.162
# Mapped_Loc           POINT (-86.775075 36.161991)
# geometry             POINT (-86.775075 36.161991)
# index_right                                    41
# name                              Urban Residents
# Name: 1140, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   16
# Route_Name                  OLD HICKORY - MADISON
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 1141, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                   16
# Route_Name                  OLD HICKORY - MADISON
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 1142, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   16
# Route_Name                  OLD HICKORY - MADISON
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 1143, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           16
# Route_Name                          OLD HICKORY - MADISON
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 1145, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           16
# Route_Name                          OLD HICKORY - MADISON
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 1146, dtype: object
# Stop_ID_Number                               209
# Stop_Abbreviation                       4AVBROSM
# Stop_Name            4TH AVE S & BROADWAY AVE SB
# Shelter                                        0
# Bench                                          1
# Route_Number                                  16
# Route_Name                 OLD HICKORY - MADISON
# Lng                                     -86.7766
# Lat                                      36.1601
# Mapped_Loc           POINT (-86.776567 36.16008)
# geometry             POINT (-86.776567 36.16008)
# index_right                                   41
# name                             Urban Residents
# Name: 1147, dtype: object
# Stop_ID_Number                               3869
# Stop_Abbreviation                         UNI5AWN
# Stop_Name                 UNION ST & 5TH AVE N WB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   16
# Route_Name                  OLD HICKORY - MADISON
# Lng                                       -86.781
# Lat                                       36.1647
# Mapped_Loc           POINT (-86.780997 36.164688)
# geometry             POINT (-86.780997 36.164688)
# index_right                                    41
# name                              Urban Residents
# Name: 1168, dtype: object
# Stop_ID_Number                                        243
# Stop_Abbreviation                                6AVCHUSN
# Stop_Name                        6TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                           17
# Route_Name                              12TH AVENUE SOUTH
# Lng                                              -86.7816
# Lat                                               36.1628
# Mapped_Loc           POINT (-86.78160099999999 36.162833)
# geometry             POINT (-86.78160099999999 36.162833)
# index_right                                            41
# name                                      Urban Residents
# Name: 1169, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   17
# Route_Name                      12TH AVENUE SOUTH
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 1170, dtype: object
# Stop_ID_Number                                263
# Stop_Abbreviation                         8ABRONM
# Stop_Name             8TH AVE S & BROADWAY AVE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   17
# Route_Name                      12TH AVENUE SOUTH
# Lng                                      -86.7826
# Lat                                       36.1597
# Mapped_Loc           POINT (-86.782557 36.159688)
# geometry             POINT (-86.782557 36.159688)
# index_right                                    41
# name                              Urban Residents
# Name: 1244, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   17
# Route_Name                      12TH AVENUE SOUTH
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 1247, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                   17
# Route_Name                      12TH AVENUE SOUTH
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 1248, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   17
# Route_Name                      12TH AVENUE SOUTH
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 1249, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           18
# Route_Name                             AIRPORT - ELM HILL
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 1250, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           18
# Route_Name                             AIRPORT - ELM HILL
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 1251, dtype: object
# Stop_ID_Number                               209
# Stop_Abbreviation                       4AVBROSM
# Stop_Name            4TH AVE S & BROADWAY AVE SB
# ...
# name                                      Urban Residents
# Name: 2481, dtype: object
# Stop_ID_Number                                702
# Stop_Abbreviation                        6AVCOMSN
# Stop_Name              6TH AVE N & COMMERCE ST SB
# Shelter                                         0
# Bench                                           1
# Route_Number                                   38
# Route_Name                        ANTIOCH EXPRESS
# Lng                                      -86.7807
# Lat                                       36.1614
# Mapped_Loc           POINT (-86.780728 36.161447)
# geometry             POINT (-86.780728 36.161447)
# index_right                                    41
# name                              Urban Residents
# Name: 2482, dtype: object
# Stop_ID_Number                                3869
# Stop_Abbreviation                          UNI5AWN
# Stop_Name                  UNION ST & 5TH AVE N WB
# Shelter                                          0
# Bench                                            1
# Route_Number                                    41
# Route_Name           GOLDEN VALLEY - TRINITY HILLS
# Lng                                        -86.781
# Lat                                        36.1647
# Mapped_Loc            POINT (-86.780997 36.164688)
# geometry              POINT (-86.780997 36.164688)
# index_right                                     41
# name                               Urban Residents
# Name: 2516, dtype: object
# Stop_ID_Number                                228
# Stop_Abbreviation                         5ACOMNN
# Stop_Name              5TH AVE N & COMMERCE ST NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   44
# Route_Name                         M.T.A. SHUTTLE
# Lng                                      -86.7792
# Lat                                       36.1617
# Mapped_Loc           POINT (-86.779169 36.161732)
# geometry             POINT (-86.779169 36.161732)
# index_right                                    41
# name                              Urban Residents
# Name: 2577, dtype: object
# Stop_ID_Number                                       3862
# Stop_Abbreviation                                 COM5AWN
# Stop_Name                         COMMERCE ST & 5TH AVE N
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           44
# Route_Name                                 M.T.A. SHUTTLE
# Lng                                              -86.7793
# Lat                                               36.1619
# Mapped_Loc           POINT (-86.77928100000001 36.161947)
# geometry             POINT (-86.77928100000001 36.161947)
# index_right                                            41
# name                                      Urban Residents
# Name: 2578, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                   44
# Route_Name                         M.T.A. SHUTTLE
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 2579, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   44
# Route_Name                         M.T.A. SHUTTLE
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 2580, dtype: object
# Stop_ID_Number                               4054
# Stop_Abbreviation                        1AVDEMSN
# Stop_Name            1ST AVE S & DEMONBREUN ST SB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   44
# Route_Name                         M.T.A. SHUTTLE
# Lng                                      -86.7733
# Lat                                       36.1603
# Mapped_Loc            POINT (-86.773258 36.16033)
# geometry              POINT (-86.773258 36.16033)
# index_right                                    41
# name                              Urban Residents
# Name: 2583, dtype: object
# Stop_ID_Number                              4140
# Stop_Abbreviation                       7AVCHUSN
# Stop_Name               7TH AVE N & CHURCH ST SB
# Shelter                                        0
# Bench                                          0
# Route_Number                                  50
# Route_Name             A.M. YELLOW STATE SHUTTLE
# Lng                                     -86.7828
# Lat                                      36.1622
# Mapped_Loc           POINT (-86.78277 36.162206)
# geometry             POINT (-86.78277 36.162206)
# index_right                                   41
# name                             Urban Residents
# Name: 2609, dtype: object
# Stop_ID_Number                                       2544
# Stop_Abbreviation                                5AVGAYNN
# Stop_Name                           5TH AVE N & GAY ST NB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                           51
# Route_Name                     A.M. NORTH PARKING SHUTTLE
# Lng                                              -86.7831
# Lat                                               36.1678
# Mapped_Loc           POINT (-86.783106 36.16782199999999)
# geometry             POINT (-86.783106 36.16782199999999)
# index_right                                            41
# name                                      Urban Residents
# Name: 2614, dtype: object
# Stop_ID_Number                                        218
# Stop_Abbreviation                                4AVCHUSN
# Stop_Name                        4TH AVE N & CHURCH ST SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           51
# Route_Name                     A.M. NORTH PARKING SHUTTLE
# Lng                                              -86.7791
# Lat                                               36.1638
# Mapped_Loc           POINT (-86.77907900000001 36.163796)
# geometry             POINT (-86.77907900000001 36.163796)
# index_right                                            41
# name                                      Urban Residents
# Name: 2616, dtype: object
# Stop_ID_Number                                       3862
# Stop_Abbreviation                                 COM5AWN
# Stop_Name                         COMMERCE ST & 5TH AVE N
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           51
# Route_Name                     A.M. NORTH PARKING SHUTTLE
# Lng                                              -86.7793
# Lat                                               36.1619
# Mapped_Loc           POINT (-86.77928100000001 36.161947)
# geometry             POINT (-86.77928100000001 36.161947)
# index_right                                            41
# name                                      Urban Residents
# Name: 2617, dtype: object
# Stop_ID_Number                                226
# Stop_Abbreviation                        5AVCHUNN
# Stop_Name                5TH AVE N & CHURCH ST NB
# Shelter                                         1
# Bench                                           1
# Route_Number                                   51
# Route_Name             A.M. NORTH PARKING SHUTTLE
# Lng                                      -86.7801
# Lat                                       36.1631
# Mapped_Loc           POINT (-86.780078 36.163054)
# geometry             POINT (-86.780078 36.163054)
# index_right                                    41
# name                              Urban Residents
# Name: 2618, dtype: object
# Stop_ID_Number                                224
# Stop_Abbreviation                        5AVCHUNM
# Stop_Name               5TH AVE N & THE ARCADE NB
# Shelter                                         0
# Bench                                           0
# Route_Number                                   51
# Route_Name             A.M. NORTH PARKING SHUTTLE
# Lng                                      -86.7806
# Lat                                       36.1639
# Mapped_Loc           POINT (-86.780627 36.163938)
# geometry             POINT (-86.780627 36.163938)
# index_right                                    41
# name                              Urban Residents
# Name: 2619, dtype: object
# Stop_ID_Number                                       2544
# Stop_Abbreviation                                5AVGAYNN
# Stop_Name                           5TH AVE N & GAY ST NB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                           51
# Route_Name                     A.M. NORTH PARKING SHUTTLE
# Lng                                              -86.7831
# Lat                                               36.1678
# Mapped_Loc           POINT (-86.783106 36.16782199999999)
# geometry             POINT (-86.783106 36.16782199999999)
# index_right                                            41
# name                                      Urban Residents
# Name: 2623, dtype: object
# Stop_ID_Number                              4140
# Stop_Abbreviation                       7AVCHUSN
# Stop_Name               7TH AVE N & CHURCH ST SB
# Shelter                                        0
# Bench                                          0
# Route_Number                                  53
# Route_Name             P.M. YELLOW STATE SHUTTLE
# Lng                                     -86.7828
# Lat                                      36.1622
# Mapped_Loc           POINT (-86.78277 36.162206)
# geometry             POINT (-86.78277 36.162206)
# index_right                                   41
# name                             Urban Residents
# Name: 2626, dtype: object
# Stop_ID_Number                                    3850
# Stop_Abbreviation                              BRO2AWN
# Stop_Name                  BROADWAY AVE & 2ND AVE N WB
# Shelter                                              0
# Bench                                                1
# Route_Number                                        93
# Route_Name           MUSIC CITY STAR -WEST END SHUTTLE
# Lng                                           -86.7751
# Lat                                             36.162
# Mapped_Loc                POINT (-86.775075 36.161991)
# geometry                  POINT (-86.775075 36.161991)
# index_right                                         41
# name                                   Urban Residents
# Name: 2632, dtype: object
# Stop_ID_Number                                   3850
# Stop_Abbreviation                             BRO2AWN
# Stop_Name                 BROADWAY AVE & 2ND AVE N WB
# Shelter                                             0
# Bench                                               1
# Route_Number                                       94
# Route_Name           MUSIC CITY STAR DOWNTOWN SHUTTLE
# Lng                                          -86.7751
# Lat                                            36.162
# Mapped_Loc               POINT (-86.775075 36.161991)
# geometry                 POINT (-86.775075 36.161991)
# index_right                                        41
# name                                  Urban Residents
# Name: 2663, dtype: object
# Stop_ID_Number                                       2722
# Stop_Abbreviation                                2AVCOMNN
# Stop_Name                      2ND AVE N & COMMERCE ST NB
# Shelter                                                 0
# Bench                                                   0
# Route_Number                                           94
# Route_Name               MUSIC CITY STAR DOWNTOWN SHUTTLE
# Lng                                               -86.776
# Lat                                               36.1632
# Mapped_Loc           POINT (-86.77599499999999 36.163214)
# geometry             POINT (-86.77599499999999 36.163214)
# index_right                                            41
# name                                      Urban Residents
# Name: 2664, dtype: object
# Stop_ID_Number                                    191
# Stop_Abbreviation                            3AVCHUNN
# Stop_Name                    3RD AVE N & CHURCH ST NB
# Shelter                                             0
# Bench                                               1
# Route_Number                                       94
# Route_Name           MUSIC CITY STAR DOWNTOWN SHUTTLE
# Lng                                          -86.7776
# Lat                                           36.1642
# Mapped_Loc               POINT (-86.777576 36.164179)
# geometry                 POINT (-86.777576 36.164179)
# index_right                                        41
# name                                  Urban Residents
# Name: 2665, dtype: object
# Stop_ID_Number                                       3457
# Stop_Abbreviation                                4AVBROSN
# Stop_Name                     4TH AVE N & BROADWAY AVE SB
# Shelter                                                 0
# Bench                                                   1
# Route_Number                                           94
# Route_Name               MUSIC CITY STAR DOWNTOWN SHUTTLE
# Lng                                              -86.7773
# Lat                                               36.1611
# Mapped_Loc           POINT (-86.77729599999999 36.161063)
# geometry             POINT (-86.77729599999999 36.161063)
# index_right                                            41
# name                                      Urban Residents
# Name: 2669, dtype: object
# Stop_ID_Number                                    209
# Stop_Abbreviation                            4AVBROSM
# Stop_Name                 4TH AVE S & BROADWAY AVE SB
# Shelter                                             0
# Bench                                               1
# Route_Number                                       94
# Route_Name           MUSIC CITY STAR DOWNTOWN SHUTTLE
# Lng                                          -86.7766
# Lat                                           36.1601
# Mapped_Loc                POINT (-86.776567 36.16008)
# geometry                  POINT (-86.776567 36.16008)
# index_right                                        41
# name                                  Urban Residents
# Name: 2670, dtype: object
# Stop_ID_Number                                    265
# Stop_Abbreviation                             8ABROSN
# Stop_Name                 8TH AVE S & BROADWAY AVE SB
# Shelter                                             1
# Bench                                               0
# Route_Number                                       96
# Route_Name           MURFREESBORO - NASHVILLE EXPRESS
# Lng                                          -86.7822
# Lat                                            36.159
# Mapped_Loc               POINT (-86.782225 36.159008)
# geometry                 POINT (-86.782225 36.159008)
# index_right                                        41
# name                                  Urban Residents
# Name: 2674, dtype: object

# %%
# iterate through urban busses and create locations and markers
# note that latitude must come first for folium map to work
for row in nash_busses.iterrows():
    row_values = row[1]
    location = [row_values['Lat'], row_values['Lng']]
    popup = (str(row_values['Stop_ID_Number']) + ': ' + str(row_values['Stop_Abbreviation']) + '<br/>' +
            'Stop Name: ' + str(row_values['Stop_Name']) + '<br/>' +
            'Route Name: ' + str(row_values['Route_Name']) + '<br/>' +
            'Shelter: ' + str(row_values['Shelter']) + '<br/>' +
            'Bench: ' + str(row_values['Bench'])).replace("'", "`")
    marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color='red', icon='bus', 
                                                                                icon_color='white', prefix='fa'))
    
    marker.add_to(downtown_map)

# display map
downtown_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# read in public health clinic location file
public_health = pd.read_csv("data/public_health_loc.csv")
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...

# %%
public_health['Location 2'] = public_health['Location 1'].apply(lambda x: x.split('\n'))
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...

# %%
print(public_health['Location 2'])
# Out:
# 0    [2500 Charlotte Avenue, Nashville, TN, (36.155...
# 1    [1015 East Trinity Lane, Nashville, TN, (36.20...
# 2    [224 Oriel Avenue, Nashville, TN, (36.122097, ...
# 3    [3718 Nolensville Pike, Nashville, TN, (36.093...
# Name: Location 2, dtype: object

# %%
public_health['Location 2'][2][2]
# Out:
# '(36.122097, -86.743627)'

# %%
public_health['Location 3'] = [loc[2] for loc in public_health['Location 2']]

# %%
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2               Location 3
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  (36.155043, -86.812991)
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  (36.204273, -86.745286)
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  (36.122097, -86.743627)
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  (36.093667, -86.736409)

# %%
public_health['Location 3'] = public_health['Location 3'].str.replace('(','')

# %%
public_health['Location 3'] = public_health['Location 3'].str.replace(')','')

# %%
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2             Location 3
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  36.155043, -86.812991
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  36.204273, -86.745286
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  36.093667, -86.736409

# %%
public_health['Location 4'] = public_health['Location 3'].str.split(',')

# %%
public_health['Lng'] = [loc[1] for loc in public_health['Location 4']]

# %%
public_health['Lat'] = [loc[0] for loc in public_health['Location 4']]

# %%
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2             Location 3  \
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  36.155043, -86.812991
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  36.204273, -86.745286
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  36.093667, -86.736409
#
#                  Location 4          Lng        Lat
# 0  [36.155043,  -86.812991]   -86.812991  36.155043
# 1  [36.204273,  -86.745286]   -86.745286  36.204273
# 2  [36.122097,  -86.743627]   -86.743627  36.122097
# 3  [36.093667,  -86.736409]   -86.736409  36.093667

# %%
public_health['Geom'] = public_health.apply(lambda x: Point((float(x.Lng), float(x.Lat))), axis=1)
public_health
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2             Location 3  \
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  36.155043, -86.812991
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  36.204273, -86.745286
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  36.093667, -86.736409
#
#                  Location 4          Lng        Lat  \
# 0  [36.155043,  -86.812991]   -86.812991  36.155043
# 1  [36.204273,  -86.745286]   -86.745286  36.204273
# 2  [36.122097,  -86.743627]   -86.743627  36.122097
# 3  [36.093667,  -86.736409]   -86.736409  36.093667
#
#                                    Geom
# 0          POINT (-86.812991 36.155043)
# 1  POINT (-86.74528599999999 36.204273)
# 2          POINT (-86.743627 36.122097)
# 3  POINT (-86.73640899999999 36.093667)

# %%
public_health_geo = gpd.GeoDataFrame(public_health, crs = neighborhoods.crs, geometry = public_health.Geom)
public_health_geo
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2             Location 3  \
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  36.155043, -86.812991
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  36.204273, -86.745286
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  36.093667, -86.736409
#
#                  Location 4          Lng        Lat  \
# 0  [36.155043,  -86.812991]   -86.812991  36.155043
# 1  [36.204273,  -86.745286]   -86.745286  36.204273
# 2  [36.122097,  -86.743627]   -86.743627  36.122097
# 3  [36.093667,  -86.736409]   -86.736409  36.093667
#
#                                    Geom                              geometry
# 0          POINT (-86.812991 36.155043)          POINT (-86.812991 36.155043)
# 1  POINT (-86.74528599999999 36.204273)  POINT (-86.74528599999999 36.204273)
# 2          POINT (-86.743627 36.122097)          POINT (-86.743627 36.122097)
# 3  POINT (-86.73640899999999 36.093667)  POINT (-86.73640899999999 36.093667)

# %%
public_health_geo['Lng'] = public_health_geo['Lng'].astype(float)

# %%
public_health_geo['Lat'] = public_health_geo['Lat'].astype(float)

# %%
pub_health = gpd.sjoin(public_health_geo, neighborhoods, op = 'within')
pub_health
# Out:
#                      Clinic Name           Phone  \
# 2  Woodbine Public Health Center  (615) 862-7940
#
#                                    Hours  \
# 2  Monday - Friday 7:00 am until 4:30 pm
#
#                                           Location 1  \
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
#
#                                           Location 2             Location 3  \
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
#
#                  Location 4        Lng        Lat  \
# 2  [36.122097,  -86.743627] -86.743627  36.122097
#
#                            Geom                      geometry  index_right  \
# 2  POINT (-86.743627 36.122097)  POINT (-86.743627 36.122097)           10
#
#        name
# 2  Woodbine

# %%
for row in pub_health.iterrows():
    row_values = row[1]
    location = [row_values['Lat'], row_values['Lng']]
    popup = (str(row_values['Clinic Name']) + '<br/>' +
            'Hours: ' + str(row_values['Hours']) + '<br/>' +
            'Phone: ' + str(row_values['Phone'])).replace("'", "`")
    marker = folium.Marker(location = location, popup = popup, icon=folium.Icon(color='green', icon='fa-hospital-o', 
                                                                                icon_color='white', prefix='fa'))
    
    marker.add_to(downtown_map)

# display map
downtown_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
zip_codes = gpd.read_file('data/zip_codes.geojson')
zip_codes.head()
# Out:
#      zip objectid    po_name      shape_stlength        shape_starea  \
# 0  37027       34  BRENTWOOD   3140.581074908484  595244.46435546875
# 1  37027       37  BRENTWOOD  3558.4949049555025  315672.26501464844
# 2  37143       29     PEGRAM   7053.537934957626   1901096.087890625
# 3  37143       28     PEGRAM  1197.1070870572601  83126.842468261719
# 4  37240       44  NASHVILLE  9240.7969963306841  3146698.6988525391
#
#                                             geometry
# 0  (POLYGON ((-86.684745973484 35.992792089723, -...
# 1  (POLYGON ((-86.719974241412 36.009524281615, -...
# 2  (POLYGON ((-87.03537311557 36.087623620297, -8...
# 3  (POLYGON ((-87.03605109734001 36.095325458066,...
# 4  (POLYGON ((-86.803254434485 36.149298486807, -...

# %%
bus_stops_geo = gpd.GeoDataFrame(mta_stops, crs = zip_codes.crs, geometry = mta_stops.Mapped_Loc)

# %%
pub_health_clinic = gpd.GeoDataFrame(public_health, crs = zip_codes.crs, geometry = public_health_geo.Geom)

# %%
bus_stops_loc = gpd.sjoin(bus_stops_geo, zip_codes, op = 'within')
bus_stops_loc.head()
# Out:
#    Stop_ID_Number Stop_Abbreviation                        Stop_Name  Shelter  \
# 0            1788           100OAKS                    100 OAKS MALL        1
# 1            1792          POWPOWNM        POWELL AVE & POWELL PL NB        0
# 2            1785          BRAEIRNN  BRANSFORD AVE & EAST IRIS DR NB        0
# 3            1787          BRABERNM      BRANSFORD AVE & BERRY RD NB        0
# 4             461          BRAROSNN  BRANSFORD AVE & ROSEDALE AVE NB        0
#
#    Bench  Route_Number Route_Name        Lng        Lat  \
# 0      1             1  VINE HILL -86.762639  36.106851
# 1      0             1  VINE HILL -86.765569  36.108232
# 2      1             1  VINE HILL -86.766280  36.116603
# 3      0             1  VINE HILL -86.765494  36.121603
# 4      0             1  VINE HILL -86.765827  36.124624
#
#                              Mapped_Loc                              geometry  \
# 0  POINT (-86.76263900000001 36.106851)  POINT (-86.76263900000001 36.106851)
# 1          POINT (-86.765569 36.108232)          POINT (-86.765569 36.108232)
# 2  POINT (-86.76628000000001 36.116603)  POINT (-86.76628000000001 36.116603)
# 3  POINT (-86.76549399999999 36.121603)  POINT (-86.76549399999999 36.121603)
# 4          POINT (-86.765827 36.124624)          POINT (-86.765827 36.124624)
#
#    index_right    zip objectid    po_name      shape_stlength  \
# 0           50  37204       14  NASHVILLE  94532.925240739496
# 1           50  37204       14  NASHVILLE  94532.925240739496
# 2           50  37204       14  NASHVILLE  94532.925240739496
# 3           50  37204       14  NASHVILLE  94532.925240739496
# 4           50  37204       14  NASHVILLE  94532.925240739496
#
#          shape_starea
# 0  201037271.83300781
# 1  201037271.83300781
# 2  201037271.83300781
# 3  201037271.83300781
# 4  201037271.83300781

# %%
pub_health_loc = gpd.sjoin(pub_health_clinic, zip_codes, op = 'within')
pub_health_loc.head()
# Out:
#                                        Clinic Name           Phone  \
# 0                       Lentz Public Health Center  (615) 340-5616
# 1                        East Public Health Center  (615) 862-7916
# 2                    Woodbine Public Health Center  (615) 862-7940
# 3  South Nashville WIC Nutrition Center (WIC Only)  (615) 880-3210
#
#                                                Hours  \
# 0              Monday - Friday 8:00 am until 4:30 pm
# 1              Monday - Friday 7:30 am until 4:30 pm
# 2              Monday - Friday 7:00 am until 4:30 pm
# 3  Monday – Thursday  7:30 am – 6:00 pm; Friday 7...
#
#                                           Location 1  \
# 0  2500 Charlotte Avenue\nNashville, TN\n(36.1550...
# 1  1015 East Trinity Lane\nNashville, TN\n(36.204...
# 2  224 Oriel Avenue\nNashville, TN\n(36.122097, -...
# 3  3718 Nolensville Pike\nNashville, TN\n(36.0936...
#
#                                           Location 2             Location 3  \
# 0  [2500 Charlotte Avenue, Nashville, TN, (36.155...  36.155043, -86.812991
# 1  [1015 East Trinity Lane, Nashville, TN, (36.20...  36.204273, -86.745286
# 2  [224 Oriel Avenue, Nashville, TN, (36.122097, ...  36.122097, -86.743627
# 3  [3718 Nolensville Pike, Nashville, TN, (36.093...  36.093667, -86.736409
#
#                  Location 4        Lng        Lat  \
# 0  [36.155043,  -86.812991] -86.812991  36.155043
# 1  [36.204273,  -86.745286] -86.745286  36.204273
# 2  [36.122097,  -86.743627] -86.743627  36.122097
# 3  [36.093667,  -86.736409] -86.736409  36.093667
#
#                                    Geom                              geometry  \
# 0          POINT (-86.812991 36.155043)          POINT (-86.812991 36.155043)
# 1  POINT (-86.74528599999999 36.204273)  POINT (-86.74528599999999 36.204273)
# 2          POINT (-86.743627 36.122097)          POINT (-86.743627 36.122097)
# 3  POINT (-86.73640899999999 36.093667)  POINT (-86.73640899999999 36.093667)
#
#    index_right    zip objectid    po_name      shape_stlength  \
# 0           25  37203       40  NASHVILLE  92627.871628329856
# 1           28  37216        5  NASHVILLE  75723.281972536992
# 2           23  37210       17  NASHVILLE   93152.89483318229
# 3           48  37211       47  NASHVILLE  291945.03008033131
#
#          shape_starea
# 0  121775086.45056152
# 1  188905252.57263184
# 2  265647980.69604492
# 3  603158707.04760742
